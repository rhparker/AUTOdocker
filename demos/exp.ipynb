# %%
# import os module
import os

# import AUTO modules
from auto import AUTOCommands as ac
from auto import AUTOclui as acl
from auto import interactiveBindings as ib
from auto import runAUTO as ra

# import plotting tools
import matplotlib as mpl
from matplotlib import pyplot as plt

# virtual display to use AUTO plot function
from pyvirtualdisplay import Display
from IPython.display import display as display
from PIL import Image
disp = Display(visible=0, size=(1366,768))
disp.start()

# %%
# use working directory for demo to avoid clutter
folder = '/auto/workspace/demos/demo'
os.chdir(folder)

# %%
# copy demo into current directory
ac.copydemo('exp')

# start AUTO with runner object
runner = ra.runAUTO()

print("\n***Compute a solution family***")
r1 = ac.run(e='exp',c='exp',runner=runner)

print("\n***Restart the solution family***")
r2 = ac.run(r1,NTST=20,runner=runner)
ac.save(r1+r2,'exp')
# Out:
# Copying demo exp ... done
#
# ***Compute a solution family***
# gfortran -fopenmp -O -c exp.f90 -o exp.o
# gfortran -fopenmp -O exp.o -o exp.exe /auto/lib/*.o
# Starting exp ...
#
#   BR    PT  TY  LAB     lambda      INTEGRAL u      MAX u         MAX v
#    1     1  EP    1   0.00000E+00   0.00000E+00   0.00000E+00   0.00000E+00
#    1    10  UZ    2   5.00071E-01   4.39344E-02   6.60050E-02   2.61316E-01
#    1    13  UZ    3   1.00000E+00   9.32569E-02   1.40484E-01   5.49353E-01
#    1    16  UZ    4   1.50000E+00   1.49861E-01   2.26457E-01   8.73235E-01
#    1    19  UZ    5   2.00000E+00   2.16936E-01   3.28922E-01   1.24822E+00
#    1    22  UZ    6   2.50000E+00   3.00803E-01   4.57926E-01   1.70436E+00
#    1    26  UZ    7   3.00001E+00   4.17958E-01   6.39959E-01   2.31962E+00
#    1    33  LP    8   3.51383E+00   7.61901E-01   1.18679E+00   4.00000E+00
#    1    43  UZ    9   3.00000E+00   1.23967E+00   1.97495E+00   6.10338E+00
# ...

# %%
# plot bifurcation diagram using plot routine from AUTO

p = ac.plot('exp')
p.savefig('b.png')
display(Image.open('b.png'))
# Out:
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7F166B828E80>

# %%
# plot some solutions (v vs u)

p = ac.plot('exp')
p.config(type='solution')
p.config(solution_y='v', solution_x='u')
p.config(label=[4,6,8,10])
p.config(color_list="black red green blue")
p.config(coloring_method="curve")
p.savefig('b.png')
display(Image.open('b.png'))
# Out:
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7F166B6D44F0>

# %%
# clean up files

ac.clean()
ac.delete('exp')
# Out:
# Deleting fort.* *.o *.exe *.*~ ... done
# Deleting b.exp ... done
# Deleting s.exp ... done
# Deleting d.exp ... done
