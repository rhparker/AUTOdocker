# %%
# import os module
import os

# import AUTO modules
from auto import AUTOCommands as ac
from auto import AUTOclui as acl
from auto import interactiveBindings as ib
from auto import runAUTO as ra

# import plotting tools
import matplotlib as mpl
from matplotlib import pyplot as plt

# virtual display to use AUTO plot function
from pyvirtualdisplay import Display
from IPython.display import display as display
from PIL import Image
disp = Display(visible=0, size=(1366,768))
disp.start()

# %%
# use working directory for demo to avoid clutter
folder = '/auto/workspace/demos/demo'
os.chdir(folder)

# %%
# copy demo into current directory
ac.copydemo('brc')

# start AUTO with runner object
runner = ra.runAUTO()

pgm = "brc"
print("\nDemo %s is started"%pgm)
print("\n%s : first run : stationary solutions"%pgm)
r1 = ac.run(e=pgm,c=pgm,runner=runner)

print("\n%s : second run : periodic solutions"%pgm)
r2 = ac.run(r1("HB1"),IPS=2,ICP=[5,11],runner=runner)

print("\n%s : third run : secondary periodic solutions"%pgm)
r3 = ac.run(r2("BP1"),ISW=-1,runner=runner)

ac.save(r1+r2+r3,pgm)
# Out:
# Copying demo brc ... done
#
# Demo brc is started
#
# brc : first run : stationary solutions
# gfortran -fopenmp -O -c brc.f90 -o brc.o
# gfortran -fopenmp -O brc.o -o brc.exe /auto/lib/*.o
# Starting brc ...
#
#   BR    PT  TY  LAB    PAR(5)        L2-NORM         U(1)          U(2)          U(3)          U(4)          U(5)          U(6)
#    1     1  EP    1   4.00000E-01   8.27972E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00
#    1     5  HB    2   5.13070E-01   8.27972E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00
#    1    11  HB    3   1.02515E+00   8.27972E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00
#    1    17  HB    4   1.59033E+00   8.27972E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00
#    1    21  HB    5   1.97999E+00   8.27972E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00
#    1    22  UZ    6   2.00000E+00   8.27972E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00   2.00000E+00
#
#  Total Time    0.168E+00
# brc ... done
#
# brc : second run : periodic solutions
# Starting brc ...
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
#   BR    PT  TY  LAB    PAR(5)        L2-NORM       MAX U(1)      MAX U(2)      MAX U(3)      MAX U(4)      MAX U(5)       PERIOD
#    2    38  BP    7   1.27121E+00   8.68310E+00   2.07249E+00   2.46703E+00   3.69249E+00   3.69249E+00   2.46703E+00   3.53049E+00
#    2    44  TR    8   1.70606E+00   8.67143E+00   2.05681E+00   2.31190E+00   3.74041E+00   3.74041E+00   2.31190E+00   3.59620E+00
#    2    46  TR    9   1.87693E+00   8.67156E+00   2.04848E+00   2.25870E+00   3.77266E+00   3.77266E+00   2.25870E+00   3.62132E+00
#    2    48  UZ   10   1.99992E+00   8.67374E+00   2.04322E+00   2.22662E+00   3.79158E+00   3.79158E+00   2.22662E+00   3.63876E+00
#
#  Total Time    0.707E+00
# brc ... done
#
# brc : third run : secondary periodic solutions
# Starting brc ...
#
#   BR    PT  TY  LAB    PAR(5)        L2-NORM       MAX U(1)      MAX U(2)      MAX U(3)      MAX U(4)      MAX U(5)       PERIOD
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
#    3    35  TR   11   1.30281E+00   8.56659E+00   2.05095E+00   2.32843E+00   2.68512E+00   3.63904E+00   2.82494E+00   3.37528E+00
#    3    49  TR   12   1.92790E+00   8.48086E+00   2.02316E+00   2.13743E+00   2.26960E+00   3.58863E+00   2.51772E+00   3.43483E+00
#    3    50  UZ   13   1.99994E+00   8.47309E+00   2.02051E+00   2.12651E+00   2.25180E+00   3.57867E+00   2.46043E+00   3.44192E+00
#
#  Total Time    0.353E+00
# brc ... done
# Saving to b.brc, s.brc, and d.brc ... done
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
# plot bifurcation diagram using plot routine from AUTO

p = ac.plot('brc')
p.config(stability=True, grid=False)
p.savefig('b.png')
display(Image.open('b.png'))

# plot solutions
p = ac.plot('brc')
p.config(type='solution')
p.config(solution_x="U(2)", solution_y="U(1)")
p.config(label=[7,9,11,13])
p.config(grid=False)
p.savefig('b.png')
display(Image.open('b.png'))
# Out:
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7F76CFE82130>
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7F76CFDF3A60>

# %%
# clean up files

ac.delete('brc')
ac.clean()
# Out:
# Deleting b.brc ... done
# Deleting s.brc ... done
# Deleting d.brc ... done
# Deleting fort.* *.o *.exe *.*~ ... done
