# %%
# import os module
import os

# import AUTO modules
from auto import AUTOCommands as ac
from auto import AUTOclui as acl
from auto import interactiveBindings as ib
from auto import runAUTO as ra

# import plotting tools
import matplotlib as mpl
from matplotlib import pyplot as plt

# virtual display to use AUTO plot function (pyplot)
from pyvirtualdisplay import Display
from IPython.display import display as display
from PIL import Image
disp = Display(visible=0, size=(1366,768))
disp.start()

# %%
# use working directory for demo to avoid clutter
folder = '/auto/workspace/demos/demo'
os.chdir(folder)

# %%
# copy demo into current directory
ac.copydemo('abc')

# start AUTO with runner object
runner = ra.runAUTO()

print("\n***Compute a stationary solution family***")
abc = ac.run(e='abc',c='abc.1',runner=runner)

print("\n***Compute periodic solution families***")
for solution in abc('HB'):
    abc=abc+ac.run(solution,c='abc.2',runner=runner)

print("\n***Relabel the output***")
ac.relabel(abc)
ac.save(abc,'abc')
# Out:
# Copying demo abc ... done
#
# ***Compute a stationary solution family***
# gfortran -fopenmp -O -c abc.f90 -o abc.o
# gfortran -fopenmp -O abc.o -o abc.exe /auto/lib/*.o
# Starting abc ...
#
#   BR    PT  TY  LAB    PAR(1)        L2-NORM         U(1)          U(2)          U(3)
#    1     1  EP    1   0.00000E+00   0.00000E+00   0.00000E+00   0.00000E+00   0.00000E+00
#    1    63  HB    2   2.04185E-01   2.10511E+00   5.87753E-01   5.56043E-01   1.94342E+00
#    1    77  HB    3   2.29836E-01   3.04038E+00   7.99139E-01   6.89422E-01   2.85131E+00
#    1    93  HB    4   2.59957E-01   4.03230E+00   9.26115E-01   6.16841E-01   3.87573E+00
#    1   110  HB    5   3.46208E-01   5.57947E+00   9.88177E-01   2.27518E-01   5.48654E+00
#    1   112  UZ    6   4.00000E-01   5.75762E+00   9.91445E-01   1.75932E-01   5.66888E+00
#
#  Total Time    0.452E-01
# abc ... done
#
# ***Compute periodic solution families***
# Starting abc ...
#
#   BR    PT  TY  LAB    PAR(1)        L2-NORM       MAX U(1)      MAX U(2)      MAX U(3)       PERIOD
#    2    53  LP    7   2.13697E-01   3.15112E+00   9.55181E-01   7.82545E-01   4.60386E+00   7.61104E+00
#    2    72  LP    8   2.11903E-01   3.71726E+00   9.94574E-01   7.87019E-01   6.76231E+00   8.28914E+00
#    2   116  UZ    9   2.50003E-01   4.38078E+00   9.97613E-01   7.31620E-01   7.42179E+00   6.53496E+00
#
#  Total Time    0.106E+00
# abc ... done
# Starting abc ...
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
#   BR    PT  TY  LAB    PAR(1)        L2-NORM       MAX U(1)      MAX U(2)      MAX U(3)       PERIOD
#    3    29  LP    7   2.24962E-01   3.20785E+00   9.32614E-01   7.65288E-01   4.12206E+00   6.52551E+00
#    3    60  UZ    8   2.50001E-01   4.30860E+00   9.88920E-01   7.25072E-01   5.87858E+00   7.92732E+00
#
#  Total Time    0.713E-01
# abc ... done
# Starting abc ...
#
#   BR    PT  TY  LAB    PAR(1)        L2-NORM       MAX U(1)      MAX U(2)      MAX U(3)       PERIOD
#    4    38  UZ    7   2.50000E-01   4.30859E+00   9.88928E-01   7.25076E-01   5.87844E+00   7.92716E+00
#
#  Total Time    0.570E-01
# abc ... done
# Starting abc ...
#
#   BR    PT  TY  LAB    PAR(1)        L2-NORM       MAX U(1)      MAX U(2)      MAX U(3)       PERIOD
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
#    5    81  UZ    7   2.49999E-01   4.38073E+00   9.97613E-01   7.31616E-01   7.42128E+00   6.53497E+00
#
#  Total Time    0.798E-01
# abc ... done
#
# ***Relabel the output***
# Relabeling done
# Saving to b.abc, s.abc, and d.abc ... done
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
# plot bifurcation diagram using plot routine from AUTO

p = ac.plot('abc')
p.config(stability=True, grid=False)
p.savefig('b.png')
display(Image.open('b.png'))

p = ac.plot('abc')
p.config(stability=True, grid=False)
p.config(bifurcation_y=['PERIOD'])
p.savefig('b.png')
display(Image.open('b.png'))
# Out:
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7FA60EF5A370>
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7FA60EE91C10>

# %%
# clean up files

ac.clean()
ac.delete('abc')
# Out:
# Deleting fort.* *.o *.exe *.*~ ... done
# Deleting b.abc ... done
# Deleting s.abc ... done
# Deleting d.abc ... done
