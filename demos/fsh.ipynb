# %%
# import os module
import os

# import AUTO modules
from auto import AUTOCommands as ac
from auto import AUTOclui as acl
from auto import interactiveBindings as ib
from auto import runAUTO as ra

# import plotting tools
import matplotlib as mpl
from matplotlib import pyplot as plt

# virtual display to use AUTO plot function
from pyvirtualdisplay import Display
from IPython.display import display as display
from PIL import Image
disp = Display(visible=0, size=(1366,768))
disp.start()

# %%
# use working directory for demo to avoid clutter
folder = '/auto/workspace/demos/demo'
os.chdir(folder)

# %%
# copy demo into current directory
ac.copydemo('fsh')

# start AUTO with runner object
runner = ra.runAUTO()

pgm = "fsh"
print("\nDemo %s is started"%pgm)
print("\n%s : first run : continuation in the period T"%pgm)
r1 = ac.run(e=pgm,c=pgm,runner=runner)
ac.save(r1, '0')

print("\n%s : second run : continuation in c and T"%pgm)
r2 = ac.run(r1("UZ4"),ICP =  [2, 11, 12, 13, 14],NINT=1,
    DS='-',UZR =  {2: [1.0,2.0,3.0,5.0,10.0]}, UZSTOP={2: 0.0}, A0=-0.1, runner=runner)
ac.save(r2, pgm)
# Out:
# Copying demo fsh ... done
#
# Demo fsh is started
#
# fsh : first run : continuation in the period T
# gfortran -fopenmp -O -c fsh.f90 -o fsh.o
# gfortran -fopenmp -O fsh.o -o fsh.exe /auto/lib/*.o
# Starting fsh ...
#
#   BR    PT  TY  LAB    PAR(11)       MIN U(1)      MAX U(1)      MAX U(2)      PAR(12)       PAR(13)       PAR(14)
#    1     1  EP    1   1.00000E-02   9.99004E-01   9.99004E-01   8.98056E-05  -9.01699E-02   9.95959E-01  -8.98056E-02
#    1     7  UZ    2   1.00000E+01   9.97550E-01   9.99004E-01   2.20414E-04  -9.01699E-02   9.95959E-01  -8.98056E-02
#    1    12  UZ    3   5.00000E+01   9.16898E-01   9.99004E-01   6.87976E-03  -9.01699E-02   9.95959E-01  -8.98056E-02
#    1    16  UZ    4   1.00000E+02   1.05009E-01   9.99004E-01   2.27269E-02  -9.01699E-02   9.95959E-01  -8.98056E-02
#    1    23  UZ    5   2.00000E+02   1.22717E-05   9.99004E-01   2.27028E-02  -9.01699E-02   9.95959E-01  -8.98056E-02
#
#  Total Time    0.139E+00
# fsh ... done
# ...

# %%
# plot solutions

p = ac.plot('fsh')
p.config(type='solution')
p.config(grid=False)
p.config(label=[6,7,8,9,10,11])
p.savefig('b.png')
display(Image.open('b.png'))
# Out:
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7F92D8BC0FA0>

# %%
# clean up files

ac.delete('0')
ac.delete('fsh')
ac.clean()
# Out:
# Deleting b.0 ... done
# Deleting s.0 ... done
# Deleting d.0 ... done
# Deleting b.fsh ... done
# Deleting s.fsh ... done
# Deleting d.fsh ... done
# Deleting fort.* *.o *.exe *.*~ ... done
