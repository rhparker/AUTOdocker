# %%
# import os module
import os

# import AUTO modules
from auto import AUTOCommands as ac
from auto import AUTOclui as acl
from auto import interactiveBindings as ib
from auto import runAUTO as ra

# import plotting tools
import matplotlib as mpl
from matplotlib import pyplot as plt

# virtual display to use AUTO plot function
from pyvirtualdisplay import Display
from IPython.display import display as display
from PIL import Image
disp = Display(visible=0, size=(1366,768))
disp.start()

# %%
# use working directory for demo to avoid clutter
folder = '/auto/workspace/demos/demo'
os.chdir(folder)

# %%
# copy demo into current directory
ac.copydemo('bru')

# start AUTO with runner object
runner = ra.runAUTO()

pgm = "bru"
print("\nDemo %s is started"%pgm)
print("\n%s : first run : time integration towards stationary state"%pgm)
r1 = ac.run(e=pgm,c=pgm,runner=runner)
ac.save(r1,pgm)
# Out:
# Copying demo bru ... done
#
# Demo bru is started
#
# bru : first run : time integration towards stationary state
# gfortran -fopenmp -O -c bru.f90 -o bru.o
# gfortran -fopenmp -O bru.o -o bru.exe /auto/lib/*.o
# Starting bru ...
#
#   BR    PT  TY  LAB      TIME      INTEGRAL U(1)   MAX U(1)      MAX U(2)
#    1     1  EP    1   0.00000E+00   1.68169E+00   2.00000E+00   3.42500E+00
#    1  1777  UZ    2   2.10000E+01   2.14192E+00   2.22002E+00   2.72500E+00
#    1  1820  UZ    3   2.15000E+01   1.76925E+00   2.00000E+00   2.82414E+00
#    1  1854  UZ    4   2.20001E+01   1.57790E+00   2.00000E+00   3.39984E+00
#    1  1880  UZ    5   2.24999E+01   1.59807E+00   2.00000E+00   3.81930E+00
#    1  1924  UZ    6   2.30000E+01   1.98996E+00   2.07328E+00   3.56188E+00
#    1  2021  UZ    7   2.35002E+01   2.69331E+00   3.16499E+00   2.72500E+00
#    1  2058  UZ    8   2.40000E+01   2.35495E+00   2.53735E+00   2.72500E+00
#    1  2140  UZ    9   2.50000E+01   1.63877E+00   2.00000E+00   3.15065E+00
#
#  Total Time    0.213E+01
# bru ... done
# Saving to b.bru, s.bru, and d.bru ... done

# %%
# plot bifurcation diagram using plot routine from AUTO

p = ac.plot('bru')
p.config(grid=False)
p.savefig('b.png')
display(Image.open('b.png'))
# Out:
# Created plot
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x480 at 0x7F7A063755E0>

# %%
# clean up files

ac.delete('bru')
ac.clean()
# Out:
# Deleting b.bru ... done
# Deleting s.bru ... done
# Deleting d.bru ... done
# Deleting fort.* *.o *.exe *.*~ ... done
